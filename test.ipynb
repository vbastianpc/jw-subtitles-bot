# %%
import requests
from urllib.parse import urlparse
from urllib.parse import parse_qs
import random
from io import StringIO
import re
import json
from typing import List, Dict

import webvtt


API_MEDIATOR = 'https://b.jw-cdn.org/apis/mediator/v1/media-items/{lang_code}/{lank}?clientType=www'
API_DOCID = 'https://b.jw-cdn.org/apis/pub-media/GETPUBMEDIALINKS?output=json&fileformat=mp4&alllangs=1&langwritten={lang_code}&txtCMSLang={lang_code}&docid={docid}&track=1'
API_PUB =   'https://b.jw-cdn.org/apis/pub-media/GETPUBMEDIALINKS?output=json&fileformat=mp4&alllangs=1&langwritten={lang_code}&txtCMSLang={lang_code}&pub={pub}&track={track}'
wol_link_api_url = "https://b.jw-cdn.org/apis/wol-link"
API_MEDIATOR_CAT = 'https://b.jw-cdn.org/apis/mediator/v1/categories/{lang_code}/{category}?detailed=1&clientType=www'
_GET_CATEGORY = 'https://www.jw.org/es/biblioteca/videos/?item=pub-jwb-082_1_VIDEO&appLanguage=S'
SEARCH = 'https://data.jw-api.org/search/query'
SAMPLE_URL = 'https://www.jw.org/finder?srcid=jwlshare&wtlocale=S&lank=pub-jwb-082_1_VIDEO'
SAMPLE_URL2 = 'https://www.jw.org/es/biblioteca/videos/#es/mediaitems/StudioMonthlyPrograms/pub-jwb-082_1_VIDEO'
SECCION_DE_VIDEOS = '[sección de videos](https://www.jw.org/es/biblioteca/videos)'
URL_LANGUAGES = 'https://data.jw-api.org/mediator/v1/languages/S/all'

# %%
# Languages
languages = requests.get(URL_LANGUAGES).json()['languages']
custom = {lang['code']: lang['vernacular'] for lang in languages}
json.dump(custom, open('languages.json', 'w'), ensure_ascii=False, indent=2)
all_langs = json.load(open('languages.json'))

# %%
class JWVideo:
    def __init__(
            self,
            title: str = None,
            url_vtt: str = None,
            url_video: str = None,
            url_image: str = None,
            duration: float = None,
            label: str = None,
            subtitled: bool = None,
            pub: str = None,
            track: int = None
            ):
        self.title = title
        self.url_vtt = url_vtt
        self.url_video = url_video
        self.url_image = url_image
        self.duration = duration
        self.label = label
        self.subtitled = subtitled
        self.pub = pub
        self.track = track
    
    def __str__(self):
        return f'JWVideo {self.title!r}, label: {self.label!r}, subtitled: {self.subtitled!r}' + (f', pub: {self.pub!r}' if self.pub else '')


class Media:
    def __init__(self):
        self._data = None

    @property
    def data(self):
        if self._data is not None:
            return self._data
        else:
            self.data = requests.get(self.url_api).json()
            return self._data

    @data.setter
    def data(self, value):
        self._data = self._data or value


class MediaLank(Media):
    def __init__(self, lang_code, lank):
        self._lang_code = lang_code
        self._lank = lank
        self._data = None

    @property
    def url_api(self) -> str:
        return API_MEDIATOR.format(lang_code=self._lang_code, lank=self._lank)
    
    @property
    def jwvideos(self) -> List[JWVideo]:
        return [
            JWVideo(
                title=self.data['media'][0]['title'],
                url_vtt=file['subtitles']['url'],
                url_video=file['progressiveDownloadURL'],
                url_image=self.data['media'][0]['images']['lss']['lg'],
                duration=file['duration'],
                label=file['label'],
                subtitled=file['subtitled']
            )   for file in self.data['media'][0]['files']
        ]
    
    @property
    def available_languages(self) -> Dict[str, str]:
        return {code: all_langs[code] for code in self.data['media'][0]['availableLanguages']}



class MediaPub(Media):
    def __init__(self, lang_code, pub, track=''):
        self._lang_code = lang_code
        self._pub = pub
        self._track = track
        self._data = None

    @property
    def url_api(self) -> str:
        return API_PUB.format(lang_code=self._lang_code, pub=self._pub, track=self._track)

    @property
    def jwvideos(self) -> List[JWVideo]:
        return [
            JWVideo(
                title=file['title'],
                url_vtt=file.get('subtitles', dict()).get('url', None),
                url_video=file['file']['url'],
                url_image=file['trackImage']['url'],
                duration=file['duration'],
                label=file['label'],
                subtitled=file['subtitled'],
                pub=self.data['pub'],
                track=file.get('track')
            ) for file in self.data['files'][self._lang_code]['MP4']
        ]
    
    @property
    def available_languages(self) -> Dict[str, str]:
        return {code: info['name'] for code, info in self.data['languages'].items()}
        


# https://www.jw.org/finder?srcid=share&wtlocale=S&lank=pub-jwbcov_201705_5_VIDEO
media = MediaPub('S', 'apv')
media.available_languages
# Out:
# {'S': 'español',
#  'E': 'inglés',
#  'ABB': 'abé',
#  'ABK': 'abjasio',
#  'AU': 'abua',
#  'ACH': 'achí',
#  'AC': 'acholi',
#  'AF': 'afrikáans',
#  'AHN': 'ahanta',
#  'AP': 'aimara',
#  'AKA': 'akha',
#  'AL': 'albanés',
#  'X': 'alemán',
#  'XSW': 'alemán suizo',
#  'ALT': 'altaico',
#  'ALU': 'aluro',
#  'AM': 'amárico',
#  'AI': 'amis',
#  'AMG': 'amuzgo de Guerrero',
#  'A': 'árabe',
#  'AEY': 'árabe de Egipto',
#  'ASN': 'árabe sudanés',
#  'REA': 'armenio',
#  'R': 'armenio occidental',
#  'KRB': 'armenio oriental',
#  'AE': 'asamés',
#  'AHK': 'asháninka',
#  'IE': 'ateso',
#  'ATI': 'atié',
#  'AKN': 'aucano',
#  'AJG': 'ayá',
#  'AJR': 'azerí',
#  'LWX': 'bajo alemán',
#  'BAK': 'bashkir',
#  'BS': 'bassa de Camerún',
#  'BA': 'bassa de Liberia',
#  'BTK': 'batak simalunguno',
#  'AK': 'batako karo',
#  'BT': 'batako toba',
#  'AO': 'baulé',
#  'BI': 'becol',
#  'BE': 'bengalí',
#  'ET': 'bete',
#  'IK': 'biak',
#  'BU': 'birmano',
#  'LM': 'bislama',
#  'BO': 'boulou',
#  'BL': 'búlgaro',
#  'KBV': 'caboverdés',
#  'CQ': 'cakchiquel occidental',
#  'CB': 'camboyano',
#  'CRB': 'caribe',
#  'AN': 'catalán',
#  'CV': 'cebuano',
#  'CC': 'chabacano',
#  'CGM': 'changana (mozambique)',
#  'B': 'checo',
#  'KBR': 'cherkés kabardino',
#  'CN': 'chichewa',
#  'CGG': 'chiga',
#  'HK': 'chin haka',
#  'CNS': 'chino cantonés (simplificado)',
#  'CHC': 'chino cantonés (tradicional)',
#  'CHS': 'chino mandarín (simplificado)',
#  'CH': 'chino mandarín (tradicional)',
#  'CG': 'chitonga',
#  'CT': 'chitonga de Malaui',
#  'CGW': 'chitonga de Zimbabue',
#  'TB': 'chitumbuka',
#  'YA': 'chiyao',
#  'CK': 'chokue',
#  'CHL': 'chol',
#  'CLX': 'chontal de Oaxaca',
#  'CLT': 'chontal de Tabasco',
#  'CPI': 'chopi',
#  'CO': 'chuabo',
#  'CHJ': 'chuj',
#  'CU': 'chuvash',
#  'CW': 'cibemba',
#  'NM': 'cinamwanga',
#  'SN': 'cingalés',
#  'MK': 'congo',
#  'KO': 'coreano',
#  'SC': 'criollo de las Seychelles',
#  'MTC': 'criollo de Martinica',
#  'RCR': 'criollo de Reunión',
#  'GCR': 'criollo guadalupeño',
#  'GNC': 'criollo guayanés',
#  'TCR': 'criollo guineano',
#  'CR': 'criollo haitiano',
#  'BZK': 'criollo inglés de Belice',
#  'JCR': 'criollo jamaicano',
#  'CE': 'criollo mauriciano',
#  'LUC': 'criollo santalucense',
#  'C': 'croata',
#  'DGA': 'dagaari',
#  'DMR': 'damara',
#  'D': 'danés',
#  'DG': 'dangme',
#  'DAR': 'dari',
#  'LF': 'dehu',
#  'DI': 'dinka',
#  'JL': 'diula',
#  'DA': 'duala',
#  'ED': 'edo',
#  'EF': 'efik',
#  'EMC': 'emberá chamí',
#  'EMP': 'emberá del norte',
#  'EMB': 'emberá katío',
#  'MBD': 'embunda',
#  'NDA': 'endáu',
#  'NBL': 'endebele',
#  'NBZ': 'endebele de Zimbabue',
#  'OD': 'endonga',
#  'NMB': 'enguiembón',
#  'NZ': 'enzema',
#  'V': 'eslovaco',
#  'SV': 'esloveno',
#  'ST': 'estonio',
#  'BQ': 'euskera',
#  'EW': 'ewe',
#  'FGN': 'fang',
#  'FA': 'fanti',
#  'FI': 'finlandés',
#  'FN': 'fiyiano',
#  'FO': 'fon',
#  'FF': 'frafra',
#  'F': 'francés',
#  'GA': 'ga',
#  'W': 'galés',
#  'GLC': 'gallego',
#  'GRF': 'garífuna',
#  'GE': 'georgiano',
#  'GTN': 'gitonga',
#  'GN': 'gokana',
#  'GHM': 'gomala',
#  'G': 'griego',
#  'GI': 'guaraní',
#  'GIB': 'guaraní boliviano',
#  'GUR': 'gueré',
#  'GU': 'gujarati',
#  'EG': 'gun',
#  'UN': 'guna',
#  'HMA': 'hamshen (armenio)',
#  'HMS': 'hamshen (cirílico)',
#  'HA': 'hausa',
#  'HVU': 'havu',
#  'HY': 'haya',
#  'Q': 'hebreo',
#  'HR': 'herero',
#  'HV': 'hiligaynon',
#  'HI': 'hindi',
#  'MO': 'hiri motu',
#  'HM': 'hmong (blanco)',
#  'O': 'holandés',
#  'HCH': 'huichol',
#  'H': 'húngaro',
#  'HSK': 'hunsrik',
#  'IA': 'iban',
#  'IG': 'ibanag',
#  'IBI': 'ibinda',
#  'IB': 'ibo',
#  'ID': 'idoma',
#  'IGE': 'igede',
#  'IJ': 'ijaw',
#  'IL': 'ilocano',
#  'IN': 'indonesio',
#  'ELI': 'inglés liberiano',
#  'IH': 'ishan',
#  'IC': 'islandés',
#  'IS': 'isoko',
#  'I': 'italiano',
#  'IT': 'itsekiri',
#  'IXL': 'ixil',
#  'J': 'japonés',
#  'JA': 'javanés',
#  'KAB': 'kabiye',
#  'AH': 'kachin',
#  'KL': 'kalanga de Botsuana',
#  'KB': 'kamba',
#  'KA': 'kannada',
#  'KD': 'kaonde',
#  'CQC': 'kaqchikel (Chimaltenango)',
#  'KR': 'karen sgaw',
#  'AZ': 'kazajo',
#  'GK': 'kekchí',
#  'OG': 'khana',
#  'KG': 'kikongo',
#  'KQ': 'kikuyu',
#  'KU': 'kiluba',
#  'KIM': 'kimbundu',
#  'KIN': 'kinande',
#  'YW': 'kiniaruanda',
#  'KIP': 'kipende',
#  'KZ': 'kirguís',
#  'GB': 'kiribatiano',
#  'RU': 'kirundi',
#  'KI': 'kisi',
#  'KSN': 'kisonge',
#  'KT': 'konkani (alfabeto latino)',
#  'KP': 'kpelle',
#  'KRI': 'krío',
#  'RD': 'kurdo kurmanyí',
#  'RDC': 'kurdo kurmanyí (alfabeto cirílico)',
#  'RDU': 'kurdo kurmanyí del Cáucaso',
#  'WG': 'kwangalí',
#  'KY': 'kwanyama',
#  'NKN': 'kyangonde',
#  'LAH': 'lahú',
#  'LA': 'lao',
#  'LSA': 'lengua de señas argentina',
#  'BVL': 'lengua de señas boliviana',
#  'SCH': 'lengua de señas chilena',
#  'LSC': 'lengua de señas colombiana',
#  'SCR': 'lengua de señas costarricense',
#  'SEC': 'lengua de señas ecuatoriana',
#  'LSM': 'lengua de señas mexicana',
#  'LSP': 'lengua de señas paraguaya',
#  'LSS': 'lengua de señas salvadoreña',
#  'LSV': 'lengua de señas venezolana',
#  'LSE': 'lengua de signos española',
#  'DGS': 'lenguaje de señas alemán',
#  'ASL': 'lenguaje de señas americano',
#  'LAS': 'lenguaje de señas angoleño',
#  'AUS': 'lenguaje de señas australiano',
#  'OGS': 'lenguaje de señas austríaco',
#  'WSL': 'lenguaje de señas botsuano',
#  'LSB': 'lenguaje de señas brasileño',
#  'BSL': 'lenguaje de señas británico',
#  'CSE': 'lenguaje de señas checo',
#  'CSL': 'lenguaje de señas chino',
#  'CGS': 'lenguaje de señas congoleño',
#  'KSL': 'lenguaje de señas coreano',
#  'LSI': 'lenguaje de señas costamarfileño',
#  'HZJ': 'lenguaje de señas croata',
#  'CBS': 'lenguaje de señas cubano',
#  'LSQ': 'lenguaje de señas de Quebec',
#  'VSL': 'lenguaje de señas eslovaco',
#  'ESL': 'lenguaje de señas etíope',
#  'FSL': 'lenguaje de señas filipino',
#  'FID': 'lenguaje de señas finlandés',
#  'LSF': 'lenguaje de señas francés',
#  'GHS': 'lenguaje de señas ghanés',
#  'GSL': 'lenguaje de señas griego',
#  'LSG': 'lenguaje de señas guatemalteco',
#  'SHO': 'lenguaje de señas hondureño',
#  'HDF': 'lenguaje de señas húngaro',
#  'INS': 'lenguaje de señas indio',
#  'INI': 'lenguaje de señas indonesio',
#  'ISL': 'lenguaje de señas italiano',
#  'JML': 'lenguaje de señas jamaicano',
#  'JSL': 'lenguaje de señas japonés',
#  'KSI': 'lenguaje de señas keniano',
#  'BIM': 'lenguaje de señas malasio',
#  'MSL': 'lenguaje de señas malauí',
#  'TTM': 'lenguaje de señas malgache',
#  'MNS': 'lenguaje de señas melanesio',
#  'SLM': 'lenguaje de señas mozambiqueño',
#  'LSN': 'lenguaje de señas nicaragüense',
#  'NNS': 'lenguaje de señas nigeriano',
#  'PSL': 'lenguaje de señas panameño',
#  'SPE': 'lenguaje de señas peruano',
#  'PDF': 'lenguaje de señas polaco',
#  'LGP': 'lenguaje de señas portugués',
#  'RWS': 'lenguaje de señas ruandés',
#  'LMG': 'lenguaje de señas rumano',
#  'RSL': 'lenguaje de señas ruso',
#  'SWS': 'lenguaje de señas suazi',
#  'SAS': 'lenguaje de señas sudafricano',
#  'SSL': 'lenguaje de señas sueco',
#  'SGS': 'lenguaje de señas suizoalemán',
#  'SSU': 'lenguaje de señas surinamés',
#  'SIL': 'lenguaje de señas tai',
#  'TSL': 'lenguaje de señas taiwanés',
#  'TZL': 'lenguaje de señas tanzano',
#  'TKL': 'lenguaje de señas turco',
#  'ZAS': 'lenguaje de señas zambiano',
#  'ZSL': 'lenguaje de señas zimbabuense',
#  'LJ': 'lenie',
#  'LT': 'letón',
#  'LHK': 'lhukonzo',
#  'LI': 'lingala',
#  'L': 'lituano',
#  'LE': 'lomue',
#  'LU': 'luganda',
#  'LD': 'lunda',
#  'LO': 'luo',
#  'LV': 'luvale',
#  'LX': 'luxemburgués',
#  'MC': 'macedonio',
#  'MAC': 'macua',
#  'MKA': 'maka',
#  'MY': 'malayálam',
#  'ML': 'malayo',
#  'MG': 'malgache',
#  'MT': 'maltés',
#  'MZ': 'mam',
#  'MWL': 'mambue-lungu',
#  'MNO': 'mano',
#  'MYW': 'manyawa',
#  'MPD': 'mapudungun',
#  'MR': 'maratí',
#  'MTN': 'matengo',
#  'MAY': 'maya',
#  'MYO': 'mayo',
#  'MAZ': 'mazateco de Huautla',
#  'DU': 'medumba',
#  'UU': 'meru',
#  'MGL': 'mingreliano',
#  'CHW': 'minnán de Taiwán',
#  'MIS': 'misquito',
#  'MX': 'mixe medio',
#  'MXG': 'mixteco de Guerrero',
#  'MXO': 'mixteco de Huajuapan',
#  'MXT': 'mixteco de Tlaxiaco',
#  'LS': 'mizo',
#  'KHA': 'mongol',
#  'MM': 'more',
#  'MTU': 'motu',
#  'NHG': 'náhuatl de Guerrero',
#  'NHH': 'náhuatl de la Huasteca',
#  'NHV': 'náhuatl de Veracruz',
#  'NHC': 'náhuatl del centro',
#  'NHT': 'náhuatl del norte de Puebla',
#  'NV': 'navajo',
#  'NP': 'nepalés',
#  'NGB': 'ngäbere (o guaymí)',
#  'NGM': 'ngigua de San Marcos Tlacoyalco',
#  'NI': 'nias',
#  'NC': 'nicobarés',
#  'NN': 'niueano',
#  'N': 'noruego',
#  'NK': 'nyaneka',
#  'NYU': 'nyungwe',
#  'CIN': 'ñanya',
#  'NGL': 'ñemba',
#  'OBL': 'obolo',
#  'OKP': 'okpe',
#  'OI': 'oriya',
#  'OA': 'oromo',
#  'OSS': 'osético',
#  'OT': 'otetela',
#  'OTE': 'otomí de la sierra oriental',
#  'OTS': 'otomí del Estado de México',
#  'OTM': 'otomí del valle del Mezquital',
#  'PN': 'pangasinán',
#  'PAA': 'papiamento de Aruba',
#  'PA': 'papiamento de Curazao',
#  'PR': 'persa',
#  'PHM': 'phimbi',
#  'PGW': 'pidgin (oeste de África)',
#  'PCM': 'pidgin camerunés',
#  'HWP': 'pidgin de Hawái',
#  'SP': 'pidgin de las islas Salomón',
#  'NGP': 'pidgin nigeriano',
#  'PQM': 'pocomchí',
#  'P': 'polaco',
#  'PMR': 'pomeranio',
#  'PPU': 'popoluca de la Sierra',
#  'JC': 'poptí',
#  'T': 'portugués de Brasil',
#  'TPO': 'portugués de Portugal',
#  'PJ': 'punyabí',
#  'PJN': 'punyabí (alfabeto shahmukhi)',
#  'TRS': 'purépecha',
#  'QUN': 'quechua ancashino',
#  'QUA': 'quechua ayacuchano',
#  'QUB': 'quechua boliviano',
#  'QU': 'quechua cuzqueño',
#  'QUL': 'quechua de Huánuco (Huallaga)',
#  'QC': 'quiché',
#  'QCC': 'quichua de Cañar',
#  'QIB': 'quichua de Chibuleo',
#  'QIC': 'quichua de Chimborazo',
#  'QII': 'quichua de Imbabura',
#  'QIP': 'quichua de Pastaza',
#  'QCS': 'quichua de Salasaca',
#  'QIT': 'quichua de Tena',
#  'RA': 'rarotongués',
#  'RMH': 'romaní de Chile',
#  'RM': 'romaní de Macedonia',
#  'RMC': 'romaní de Macedonia (alfabeto cirílico)',
#  'RMS': 'romaní del este de Eslovaquia',
#  'RMG': 'romaní del sur de Grecia',
#  'RMV': 'romaní valaco de Rusia',
#  'RN': 'ronga',
#  'M': 'rumano',
#  'RR': 'runyankore',
#  'U': 'ruso',
#  'RT': 'rutoro',
#  'SM': 'samoano',
#  'SG': 'sango',
#  'SGR': 'sanguir',
#  'SRM': 'saramacano',
#  'SHW': 'sehwi',
#  'SEN': 'sena',
#  'NEN': 'senga (zambia)',
#  'SE': 'sepedi',
#  'SPL': 'sepulana',
#  'SB': 'serbio (alfabeto cirílico)',
#  'SBO': 'serbio (alfabeto latino)',
#  'SU': 'sesoto de Lesoto',
#  'SSA': 'sesoto de Sudáfrica',
#  'TN': 'setsuana',
#  'CA': 'shona',
#  'SHU': 'shuar',
#  'DM': 'sidama',
#  'SK': 'silozi',
#  'SR': 'sranangtongo',
#  'SW': 'suajili',
#  'ZS': 'suajili del Congo',
#  'SWI': 'suati',
#  'Z': 'sueco',
#  'SD': 'sundanés',
#  'TG': 'tagalo',
#  'TH': 'tahitiano',
#  'SI': 'tai',
#  'TAL': 'talian',
#  'TL': 'tamil',
#  'TND': 'tandroy',
#  'TNK': 'tankarana',
#  'TRH': 'tarahumara del centro',
#  'TAT': 'tártaro',
#  'TJ': 'tayiko',
#  'TU': 'telugu',
#  'HST': 'tének de San Luis Potosí',
#  'TTP': 'tetun dili',
#  'TEW': 'tewe',
#  'TI': 'tigriña',
#  'TV': 'tivo',
#  'TLN': 'tlapaneco',
#  'TJO': 'tojolabal',
#  'MP': 'tok pisin',
#  'TO': 'tongano',
#  'TOT': 'totonaco',
#  'TZE': 'tseltal',
#  'SH': 'tshiluba',
#  'TS': 'tsonga',
#  'TZO': 'tsotsil',
#  'TK': 'turco',
#  'TMR': 'turcomano',
#  'VL': 'tuvaluano',
#  'VI': 'tuviniano',
#  'TW': 'twi',
#  'K': 'ucraniano',
#  'UM': 'udmurto',
#  'UR': 'uhobo',
#  'UG': 'uigur (alfabeto cirílico)',
#  'UB': 'umbundú',
#  'WO': 'uolof',
#  'UD': 'urdu',
#  'DR': 'uruund',
#  'UZ': 'uzbeko',
#  'VLC': 'valenciano',
#  'VE': 'vendal',
#  'VZ': 'vezo',
#  'VT': 'vietnamita',
#  'WA': 'wallisiano',
#  'SA': 'waray-waray',
#  'WY': 'wayuunaiki',
#  'WL': 'wolaita',
#  'XO': 'xhosa',
#  'AW': 'xitshwa',
#  'YCB': 'yacouba',
#  'EWN': 'yaundé',
#  'BM': 'yemba',
#  'YR': 'yoruba',
#  'ZN': 'zandé',
#  'ZPL': 'zapoteco de Lachiguiri',
#  'ZPV': 'zapoteco de Villa Alta',
#  'ZPI': 'zapoteco del Istmo',
#  'ZPD': 'zapoteco del Valle',
#  'ZU': 'zulú'}

# %%
lank = MediaLank('S', 'pub-jwbcov_201705_5_VIDEO')
lank.available_languages
# Out:
# {'A': 'العربية',
#  'ABB': 'Abɛ',
#  'ABK': 'аԥсуа',
#  'AC': 'Acholi',
#  'ACH': 'achi',
#  'AF': 'Afrikaans',
#  'AH': 'Kachin',
#  'AHN': 'Aɣɩnda',
#  'AJG': 'Aja',
#  'AJR': 'Azərbaycan',
#  'AK': 'Batak (Karo)',
#  'AKA': 'Akha',
#  'AKN': 'Okanisitongo',
#  'AL': 'shqip',
#  'ALU': 'Alur',
#  'AM': 'አማርኛ',
#  'AMG': 'ñoomndaa',
#  'AN': 'català',
#  'AO': 'Wawle',
#  'AP': 'Aymara',
#  'AR': 'Bamanankan',
#  'ASL': 'American Sign Language',
#  'ATI': 'Akie',
#  'AU': 'Abua',
#  'AUS': 'Auslan (Australian Sign Language)',
#  'AW': 'ciTshwa',
#  'AZ': 'қазақ',
#  'B': 'čeština',
#  'BA': 'Ɓǎsɔ́ɔ̀ (Ɖàbíɖà)',
#  'BE': 'বাংলা',
#  'BI': 'Bicol',
#  'BIM': 'Bahasa Isyarat Malaysia',
#  'BL': 'български',
#  'BM': 'Dschang',
#  'BO': 'Bulu',
#  'BQ': 'Euskara',
#  'BS': 'Basaa (Kamerun)',
#  'BSL': 'British Sign Language',
#  'BT': 'Batak (Toba)',
#  'BU': 'မြန်မာ',
#  'BVL': 'lengua de señas boliviana',
#  'BZK': 'Bileez Kriol',
#  'C': 'hrvatski',
#  'CA': 'Shona',
#  'CB': 'ខ្មែរ',
#  'CBS': 'lenguaje de señas cubano',
#  'CE': 'Kreol Morisien',
#  'CG': 'Chitonga',
#  'CGM': 'xiChangana (Moçambique)',
#  'CH': '中文繁體（國語）',
#  'CHC': '中文繁體（廣東話）',
#  'CHJ': 'chuj',
#  'CHL': "ch'ol",
#  'CHS': '中文简体（普通话）',
#  'CHW': '閩南語（台灣）',
#  'CIN': 'Cinyanja',
#  'CK': 'Chokwe',
#  'CLT': 'yokotʼan',
#  'CLX': 'lataiki',
#  'CN': 'Chichewa',
#  'CNS': '中文简体（广东话）',
#  'CO': 'Etxuwabo',
#  'CPI': 'Txitxopi',
#  'CQC': 'Kaqchikel (Chimaltenango)',
#  'CR': 'Kreyòl ayisyen',
#  'CRB': 'Kariʼnia',
#  'CSE': 'český znakový jazyk',
#  'CSL': '中国手语',
#  'CT': 'Chitonga (Malawi)',
#  'CU': 'чӑвашла',
#  'CV': 'Cebuano',
#  'CW': 'Cibemba',
#  'D': 'Dansk',
#  'DA': 'Douala',
#  'DG': 'Dangme',
#  'DGA': 'Dagaare',
#  'DGS': 'Deutsche Gebärdensprache',
#  'DM': 'Sidaamu Afoo',
#  'DMR': 'Damara',
#  'DR': 'Uruund',
#  'DU': 'Bangangté',
#  'E': 'English',
#  'ED': 'Edo',
#  'EF': 'Efịk',
#  'EG': 'Gungbe',
#  'ELI': 'Liberian English',
#  'ET': 'ˈBhɛtɩgbʋʋ',
#  'EW': 'Eʋegbe',
#  'EWN': 'Ewondo',
#  'F': 'Français',
#  'FA': 'Mfantse',
#  'FF': 'Farefare',
#  'FGN': 'Fang',
#  'FI': 'suomi',
#  'FID': 'suomalainen viittomakieli',
#  'FN': 'vakaViti',
#  'FO': 'Fɔngbe',
#  'FSL': 'Filipino Sign Language',
#  'G': 'Ελληνική',
#  'GA': 'Ga',
#  'GB': 'Kiribati',
#  'GE': 'ქართული',
#  'GHM': 'Bandjoun-Baham',
#  'GI': 'guarani',
#  'GK': 'Q’eqchi’',
#  'GLC': 'Galego',
#  'GN': 'Gokana',
#  'GRF': 'Garifuna',
#  'GRZ': 'Kpɛlɛɛwoo',
#  'GSL': 'Ελληνική Νοηματική Γλώσσα',
#  'GTN': 'Gitonga',
#  'GU': 'ગુજરાતી',
#  'GUR': 'wɛ',
#  'H': 'magyar',
#  'HA': 'Hausa',
#  'HCH': 'wixárika',
#  'HDF': 'magyar jelnyelv',
#  'HI': 'हिंदी',
#  'HK': 'Chin (Hakha)',
#  'HM': 'Hmoob Dawb',
#  'HMA': 'համշեներեն (հայերեն)',
#  'HMS': 'һамшенерен (кирилица)',
#  'HR': 'Otjiherero',
#  'HST': 'tének',
#  'HV': 'Hiligaynon',
#  'HVU': 'Ekihavu',
#  'HZJ': 'hrvatski znakovni jezik',
#  'I': 'Italiano',
#  'IA': 'Iban',
#  'IB': 'Igbo',
#  'IBI': 'Ibinda',
#  'IC': 'íslenska',
#  'ID': 'Idoma',
#  'IE': 'Ateso',
#  'IG': 'Ibanag',
#  'IGE': 'Igede',
#  'IH': 'Esan',
#  'IJ': 'Ijaw',
#  'IK': 'Biak',
#  'IL': 'Iloko',
#  'IN': 'Indonesia',
#  'INI': 'Bahasa Isyarat Indonesia',
#  'INS': 'Indian Sign Language',
#  'IS': 'Isoko',
#  'ISL': 'Lingua dei segni italiana',
#  'IT': 'Itsekiri',
#  'IXL': 'ixil',
#  'J': '日本語',
#  'JA': 'Jawa',
#  'JC': 'poptí',
#  'JL': 'Jula',
#  'JSL': '日本手話',
#  'JWK': 'Yuwei',
#  'K': 'українська',
#  'KA': 'ಕನ್ನಡ',
#  'KAB': 'Kabɩyɛ',
#  'KB': 'Kikamba',
#  'KBV': 'Kabuverdianu',
#  'KD': 'Kikaonde',
#  'KG': 'Kikongo',
#  'KHA': 'монгол',
#  'KI': 'Kisiei',
#  'KIM': 'Kimbundu',
#  'KIP': 'Kipende',
#  'KO': '한국어',
#  'KP': 'Kpelle',
#  'KQ': 'Gĩkũyũ',
#  'KR': 'ကညီ(စှီၤ)ကျိာ်',
#  'KRB': 'Հայերեն (արևելյան բարբառ)',
#  'KRI': 'Krio',
#  'KSI': 'Kenyan Sign Language',
#  'KSL': '한국 수어',
#  'KSN': 'Kisongye',
#  'KT': 'Konkani (Romi)',
#  'KU': 'Kiluba',
#  'KY': 'Oshikwanyama',
#  'KZ': 'кыргыз',
#  'L': 'lietuvių',
#  'LA': 'ລາວ',
#  'LAH': 'Laˇhuˍ hkawˇ',
#  'LAS': 'Língua angolana de sinais',
#  'LD': 'Lunda',
#  'LE': 'Elomwe',
#  'LF': 'Drehu',
#  'LGP': 'Língua Gestual Portuguesa',
#  'LHK': 'Lhukonzo',
#  'LI': 'Lingala',
#  'LJ': 'Cilenje',
#  'LM': 'Bislama',
#  'LMG': 'Limbajul semnelor românesc',
#  'LO': 'Dholuo',
#  'LS': 'Mizo',
#  'LSA': 'lengua de señas argentina',
#  'LSB': 'Língua brasileira de sinais',
#  'LSC': 'lengua de señas colombiana',
#  'LSE': 'lengua de signos española',
#  'LSF': 'Langue des signes française',
#  'LSG': 'lenguaje de señas guatemalteco',
#  'LSI': 'Langue des signes ivoirienne',
#  'LSM': 'lengua de señas mexicana',
#  'LSN': 'lenguaje de señas nicaragüense',
#  'LSP': 'lengua de señas paraguaya',
#  'LSS': 'lengua de señas salvadoreña',
#  'LSV': 'lengua de señas venezolana',
#  'LT': 'latviešu',
#  'LU': 'Luganda',
#  'LUC': 'Kwéyòl (Patwa)',
#  'LV': 'Luvale',
#  'LWX': 'Plautdietsch',
#  'M': 'Română',
#  'MAC': 'Emakhuwa',
#  'MAY': 'maaya',
#  'MAZ': 'énná',
#  'MBD': 'Mbunda',
#  'MC': 'македонски',
#  'MG': 'Malagasy',
#  'MGL': 'მარგალური',
#  'MIS': 'miskitu',
#  'MK': 'Kikongo (Rép. dém. du congo)',
#  'MKA': 'Makaa',
#  'ML': 'Melayu',
#  'MM': 'Moore',
#  'MNO': 'Maa',
#  'MO': 'Hiri Motu',
#  'MP': 'Tok Pisin',
#  'MPD': 'mapudungun',
#  'MR': 'मराठी',
#  'MSL': 'Chinenero Chamanja cha ku Malawi',
#  'MT': 'Malti',
#  'MTU': 'Motu',
#  'MWL': 'Cimambwe-Lungu',
#  'MX': 'ayuk',
#  'MXG': 'tu’un sâví',
#  'MXO': 'Tu̱ʼun ndaʼví',
#  'MXT': 'saʼan savi',
#  'MY': 'മലയാളം',
#  'MYO': "yoremnok'ki",
#  'MZ': 'mam',
#  'N': 'Norsk',
#  'NBL': 'IsiNdebele',
#  'NBZ': 'Ndebele (Zimbabwe)',
#  'NDA': 'Cindau',
#  'NEN': 'Cinsenga',
#  'NGB': 'ngäbere',
#  'NGL': 'Ngangela',
#  'NGM': 'ngigua de San Marcos Tlacoyalco',
#  'NGP': 'Nigerian Pidgin',
#  'NHC': 'náhuatl del centro',
#  'NHG': 'náhuatl de guerrero',
#  'NHH': 'náhuatl de la huasteca',
#  'NHT': 'náhuatl del norte de Puebla',
#  'NHV': 'náhuatl de Veracruz',
#  'NI': 'Nias',
#  'NK': 'Nyaneka',
#  'NM': 'Cinamwanga',
#  'NMB': 'Ngiemboon',
#  'NNS': 'Nigerian Sign Language',
#  'NP': 'नेपाली',
#  'NV': 'Diné Bizaad',
#  'NYU': 'Cinyungwe',
#  'NZ': 'Nzema',
#  'O': 'Nederlands',
#  'OA': 'Afaan Oromoo',
#  'OBL': 'Obolo',
#  'OD': 'Oshindonga',
#  'OG': 'Khana',
#  'OKP': 'Okpe',
#  'OSS': 'ирон',
#  'OT': 'Ɔtɛtɛla',
#  'OTE': 'ñuhü',
#  'OTM': 'Ñañu',
#  'OTS': 'ñätho',
#  'P': 'polski',
#  'PA': 'Papiamentu (Kòrsou)',
#  'PCM': 'Pidgin for Cameroon',
#  'PDF': 'polski język migowy',
#  'PGW': 'Pidgin (West Africa)',
#  'PJ': 'ਪੰਜਾਬੀ',
#  'PJN': 'پنجابی (شاہ مُکھی)',
#  'PN': 'Pangasinan',
#  'PPU': 'popoluca de la Sierra',
#  'PQM': "poqomchi'",
#  'PR': 'فارسی',
#  'PSL': 'lenguaje de señas panameño',
#  'Q': 'עברית',
#  'QC': 'quiché',
#  'QCC': 'quichua (cañar)',
#  'QCS': 'quichua (salasaca)',
#  'QIB': 'quichua (chibuleo)',
#  'QIC': 'quichua (chimborazo)',
#  'QII': 'quichua (imbabura)',
#  'QIP': 'quichua (pastaza)',
#  'QIT': 'quichua (tena)',
#  'QU': 'quechua (Cusco)',
#  'QUA': 'Quechua (Ayacucho)',
#  'QUB': 'Quechua (Bolivia)',
#  'QUN': 'Quechua (Ancash)',
#  'R': 'Արեւմտահայերէն',
#  'RA': 'Reo Rarotonga',
#  'RDU': 'Kurdî Kurmancî (Kavkazûs)',
#  'REA': 'Հայերեն',
#  'RM': 'romane (Makedonija)',
#  'RMC': 'романе (Македонија) кирилица',
#  'RN': 'Xironga',
#  'RR': 'Runyankore',
#  'RSL': 'русский жестовый',
#  'RT': 'Rutoro',
#  'RU': 'Ikirundi',
#  'S': 'español',
#  'SA': 'Waray-Waray',
#  'SAS': 'South African Sign Language',
#  'SB': 'српски (ћирилица)',
#  'SBO': 'srpski (latinica)',
#  'SCH': 'lengua de señas chilena',
#  'SCR': 'lengua de señas costarricense',
#  'SD': 'Sunda',
#  'SE': 'Sepedi',
#  'SEC': 'lengua de señas ecuatoriana',
#  'SEN': 'Cisena',
#  'SG': 'Sango',
#  'SH': 'Tshiluba',
#  'SHO': 'lenguaje de señas hondureño',
#  'SHU': 'shuar',
#  'SHW': 'Sehwi',
#  'SI': 'ไทย',
#  'SIL': 'ภาษามือไทย',
#  'SK': 'Silozi',
#  'SM': 'Faa-Samoa',
#  'SN': 'සිංහල',
#  'SP': 'Solomon Islands Pidgin',
#  'SPE': 'lenguaje de señas peruano',
#  'SPL': 'Sepulana',
#  'SR': 'Sranantongo',
#  'SRM': 'Saamakatöngö',
#  'SSA': 'Sesotho (South Africa)',
#  'SSL': 'Svenskt teckenspråk',
#  'ST': 'eesti',
#  'STD': 'eesti viipekeel',
#  'SU': 'Sesotho (Lesotho)',
#  'SV': 'slovenščina',
#  'SW': 'Kiswahili',
#  'SWI': 'SiSwati',
#  'T': 'Português (Brasil)',
#  'TAL': 'Talian',
#  'TAT': 'татар',
#  'TB': 'Chitumbuka',
#  'TG': 'Tagalog',
#  'TH': 'Tahiti',
#  'TI': 'ትግርኛ',
#  'TJ': 'тоҷикӣ',
#  'TJO': 'tojol-abʼal',
#  'TK': 'Türkçe',
#  'TL': 'தமிழ்',
#  'TLN': 'me̱ʼpha̱a̱',
#  'TMR': 'türkmen',
#  'TN': 'Setswana',
#  'TND': 'Tandroy',
#  'TNK': 'Tankarana',
#  'TO': 'Faka-Tonga',
#  'TOT': 'totonaco',
#  'TPO': 'Português (Portugal)',
#  'TRH': 'ralámuli',
#  'TRS': 'Purépecha',
#  'TS': 'Xitsonga',
#  'TSL': '台灣手語',
#  'TTM': 'Tenin’ny Tanana Malagasy',
#  'TTP': 'Tetun Dili',
#  'TU': 'తెలుగు',
#  'TV': 'Tiv',
#  'TW': 'Twi',
#  'TZE': 'tseltal',
#  'TZO': 'tsotsil',
#  'U': 'русский',
#  'UB': 'Umbundu',
#  'UD': 'اُردو',
#  'UG': 'Уйғур (кирилл йезиғи)',
#  'UN': 'dule',
#  'UR': 'Urhobo',
#  'UZ': 'ўзбекча',
#  'V': 'slovenčina',
#  'VE': 'Luvenda',
#  'VI': 'тыва',
#  'VL': 'Tuvalu',
#  'VLC': 'valencià',
#  'VT': 'Việt',
#  'VZ': 'Vezo',
#  'WA': "Faka'uvea",
#  'WG': 'Rukwangali',
#  'WL': 'Wolayttattuwaa',
#  'WO': 'wolof',
#  'WSL': 'Botswana Sign Language',
#  'WY': 'Wayuunaiki',
#  'X': 'Deutsch',
#  'XO': 'IsiXhosa',
#  'YA': 'Chiyao',
#  'YCB': 'Yaoba',
#  'YR': 'Yorùbá',
#  'YW': 'Ikinyarwanda',
#  'Z': 'Svenska',
#  'ZAS': 'Zambian Sign Language',
#  'ZN': 'Zande',
#  'ZPD': 'ditsa',
#  'ZPI': 'diidxazá',
#  'ZPL': 'diitza',
#  'ZPV': 'didza xhidza',
#  'ZPX': 'Dillexhon',
#  'ZS': 'Kiswahili (Congo)',
#  'ZSL': 'Zimbabwe Sign Language',
#  'ZU': 'IsiZulu'}

# %%
class Subtitles:
    def __init__(self, jwurl=None, lang_code=None, lank=None, docid=None, pub=None, track=None):
        if jwurl:
            lang_code, lank, docid, pub, track = self.parse_jwurl()

        print(url_api)
        return
        data = requests.get(url_api).json()


        self.url_subtitles = self.get_url_subtitles()
        self.text_subtitles = self.get_text_subtitles(self.url_subtitles)
        self.text_transcription = self.get_text_transcription(self.text_subtitles, self.title)
        self.photo = None

    def parse_jwurl(self):
        up = urlparse(self.url)
        pq = parse_qs(up.query)
        lang_code = lank = docid = pub = track = None
        if up.path == '/finder':
            lang_code = pq['wtlocale'][0]
            lank = pq.get('lank', [''])[0]
            docid = pq.get('docid', [''])[0]
        elif '/mediaitems/' in up.fragment:
            locale, _, _, self.lank = up.fragment.split('/')
            lang_code = self.get_lang_code(self.locale)
        elif 'jw.org' in up.netloc:
            self.locale = up.path.split('/')[1]
            self.lang_code = self.get_lang_code(self.locale)
        else:
            raise ValueError(f'{self.url!r} no es un enlace válido')
        return lang_code, lank, docid, pub, track

    @staticmethod
    def get_lang_code(locale):
        for language in LANGUAGES:
            if language['locale'] == locale:
                return language['code']
        else:
            raise ValueError(f'No existe el idioma locale={locale}')

    def get_language_name(self):
        for language in LANGUAGES:
            if language['code'] == self.lang_code:
                return language['name']
        else:
            raise ValueError(f'No existe el idioma code={self.lang_code}')
    
    def get_language_vernacular(self):
        for language in LANGUAGES:
            if language['code'] == self.lang_code:
                return language['vernacular'].capitalize()
        else:
            raise ValueError(f'No existe el idioma code={self.lang_code}')

    def generate_jwurl(self):
        base = f'https://www.jw.org/finder?srcid=share&wtlocale={self.lang_code}'
        return base + f'&lank={self.lank}' if self.lank else f'&docid={self.docid}'

    def _subs_from_json(self):
        if self.lank:
            url = API_MEDIATOR.format(lang_code=self.lang_code, lank=self.lank)
            data = requests.get(url).json()
        elif self.docid:
            url = API_PUBMEDIA.format(lang_code=self.lang_code, docid=self.docid)
            data = requests.get(url).json()
        else:
            raise PubMediaNotFound
        if not data['media']:
            raise PubMediaNotFound
        logger.info('[%s %s %s](%s)', self.lang_code, self.lank, self.docid, url)
        self.title = data['media'][0]['title']
        for file in data['media'][0]['files']:
            if file.get('subtitles'):
                break
        else:
            raise SubtitleNotFound
        return file['subtitles']['url']

    def _subs_from_scrappy(self):
        browser = mechanicalsoup.StatefulBrowser(user_agent='Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/83.0.4103.97 Safari/537.36')
        response = browser.open(self.url)
        response = browser.page.find

    def get_url_subtitles(self):
        try:
            return self._subs_from_json()
        except PubMediaNotFound:
            pass

    def get_any_image(self):
        images = []
        for v in self.data['media'][0]['images'].values():
            [images.append(url) for url in v.values()]
        return random.choice(images)
        
    def get_image(self):
        try:
            return self.data['media'][0]['images']['pnr']['lg']
        except KeyError:
            return self.get_any_image()

    def get_availables_langs(self):
        return self.data['media'][0]['availableLanguages']
    
    @staticmethod
    def get_text_subtitles(url_subs):
        return requests.get(url_subs).content.decode()

    @staticmethod
    def get_text_transcription(subtitles='', title=''):
        transcription = title + '\n\n\n' if title else ''
        for caption in webvtt.read_buffer(StringIO(subtitles)):
            transcription += caption.text.replace('\n', ' ') + '\n'
            if caption.text.strip().endswith('.'):
                transcription += '\n'
        return transcription
